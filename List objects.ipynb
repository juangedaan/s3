# %% [markdown]
# **List all objects inside a bucket**

# %%
from boto3 import client

bucket_name = 'juanmb-analytics'

conn = client('s3')  # again assumes boto.cfg setup, assume AWS S3
for key in conn.list_objects(Bucket=bucket_name)['Contents']:
    print(key['Key'])
# Out:
# lb-logs/AWSLogs/093117279452/ELBAccessLogTestFile
# lb-logs/AWSLogs/093117279452/elasticloadbalancing/us-east-2/2018/03/20/093117279452_elasticloadbalancing_us-east-2_api-example-cluster-k8s-l-1dt7vk_20180320T0000Z_13.58.46.4_5aohr38v.log
# lb-logs/AWSLogs/093117279452/elasticloadbalancing/us-east-2/2018/03/20/093117279452_elasticloadbalancing_us-east-2_api-example-cluster-k8s-l-1dt7vk_20180320T0000Z_18.218.189.238_5ma06d5c.log
# lb-logs/AWSLogs/093117279452/elasticloadbalancing/us-east-2/2018/03/20/093117279452_elasticloadbalancing_us-east-2_api-example-cluster-k8s-l-1dt7vk_20180320T0000Z_18.221.5.251_3xh5g5d8.log
# lb-logs/AWSLogs/093117279452/elasticloadbalancing/us-east-2/2018/03/20/093117279452_elasticloadbalancing_us-east-2_api-example-cluster-k8s-l-1dt7vk_20180320T0500Z_18.221.5.251_w4g5ueak.log
# ...
